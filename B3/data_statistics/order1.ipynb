# %% [markdown]
# # Análise Dados
#
# * Observações sobre o conjunto de relatórios.
# * Apontamentos para melhora de códigos.
# * Apontamentos para evolução do trabalho.
#
# ---
#
# # Análise 09/06
#
# ## Análise Inicial

# %%
import pandas as pd
import numpy as np
import os

# %%
## Funções

########## -EXEMPLO DE USO- ##########
######################################

# %%
## PATH
### PC1
path_raiz = '/home/darkcover/Documentos/Work_Text/B3/Códigos/Extractor/Data/'
resultado = os.listdir(path_raiz)

# %%
print(type(resultado), len(resultado), "arquivos encontrados.")
# Out:
# <class 'list'> 230 arquivos encontrados.

# %%
os.listdir(path_raiz)
# Out:
# ['VLID3',
#  'DXCO3',
#  'RNEW4',
#  'AVLL3',
#  'RPMG3',
#  'KLAS3',
#  'ONCO3',
#  'CEPE3',
#  'CRFB3',
#  'ELET6',
#  'PASS3',
#  'VSPT3',
#  'CRPG6',
#  'ABEV3',
#  'CEGR3',
#  'GRND3',
#  'MILS3',
#  'EQTL3',
#  'EVEN3',
#  'MNDL3',
#  'MMAQ4',
#  'AESO3',
#  'CGAS3',
#  'FIGE3',
#  'PTNT4',
#  'EMAE4',
#  'EUCA3',
#  'CEPE6',
#  'MOVI3',
#  'FLRY3',
#  'PASS6',
#  'ARML3',
#  'TXRX3',
#  'CEEB6',
#  'PMAM3',
#  'GFSA3',
#  'VIVT3',
#  'AMER3',
#  'DMVF3',
#  'SYNE3',
#  'MRVE3',
#  'MTRE3',
#  'SAPR11',
#  'LTEL3B',
#  'CTNM3',
#  'OSXB3',
#  'INBR32',
#  'MYPK3',
#  'KLBN3',
#  'BIOM3',
#  'GGBR3',
#  'PNVL3',
#  'PDTC3',
#  'FHER3',
#  'EALT3',
#  'WEST3',
#  'GOAU3',
#  'NORD3',
#  'HOOT4',
#  'GUAR3',
#  'AERI3',
#  'MTSA3',
#  'BRAP99',
#  'JFEN3',
#  'NTCO3',
#  'CTSA8',
#  'PRIO3',
#  'RBNS4',
#  'NEMO6',
#  'GEPA3',
#  'POMO3',
#  'DTCY4',
#  'JOPA4',
#  'EQPA3',
#  'CESP5',
#  'LEVE3',
#  'CSED3',
#  'PETR4',
#  'JBSS3',
#  'RAIZ3',
#  'GOLL4',
#  'CMIG4',
#  'CEEB3',
# ...
